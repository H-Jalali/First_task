# %%
# !pip install git+https://github.com/H-Jalali/First_task.git
# !pip install scanpy
# !pip install leidenalg
# !pip install --upgrade pygments
# !pip install --user scikit-misc
# !pip install typing
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/H-Jalali/First_task.git
#   Cloning https://github.com/H-Jalali/First_task.git to /tmp/pip-req-build-rd53nhyh
#   Running command git clone --filter=blob:none --quiet https://github.com/H-Jalali/First_task.git /tmp/pip-req-build-rd53nhyh
#   Resolved https://github.com/H-Jalali/First_task.git to commit cc0c49a2cb4fe0a647c5b29018dd42e81c844fb4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting scvi-tools<0.16.0,>=0.15.0
#   Downloading scvi_tools-0.15.5-py3-none-any.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.5/261.5 KB 20.8 MB/s eta 0:00:00
# Collecting anndata>=0.7.5
#   Downloading anndata-0.8.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.1/96.1 KB 12.5 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=3 in /usr/local/lib/python3.9/dist-packages (from anndata>=0.7.5->scvi-tools-skeleton==0.4.0) (3.8.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.9/dist-packages (from anndata>=0.7.5->scvi-tools-skeleton==0.4.0) (5.5.0)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.9/dist-packages (from anndata>=0.7.5->scvi-tools-skeleton==0.4.0) (1.10.1)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.9/dist-packages (from anndata>=0.7.5->scvi-tools-skeleton==0.4.0) (1.22.4)
# Requirement already satisfied: pandas>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from anndata>=0.7.5->scvi-tools-skeleton==0.4.0) (1.4.4)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.9/dist-packages (from anndata>=0.7.5->scvi-tools-skeleton==0.4.0) (23.0)
# Requirement already satisfied: tqdm>=4.56.0 in /usr/local/lib/python3.9/dist-packages (from scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (4.65.0)
# Collecting pyro-ppl>=1.6.0
#   Downloading pyro_ppl-1.8.4-py3-none-any.whl (730 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 730.7/730.7 KB 54.2 MB/s eta 0:00:00
# Requirement already satisfied: openpyxl>=3.0 in /usr/local/lib/python3.9/dist-packages (from scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (3.0.10)
# Requirement already satisfied: jax>=0.3 in /usr/local/lib/python3.9/dist-packages (from scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.4.6)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.9/dist-packages (from scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (7.7.1)
# Collecting numpyro
#   Downloading numpyro-0.11.0-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.2/300.2 KB 33.7 MB/s eta 0:00:00
# Collecting docrep>=0.3.2
#   Downloading docrep-0.3.2.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn>=0.21.2 in /usr/local/lib/python3.9/dist-packages (from scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (1.2.2)
# Requirement already satisfied: optax in /usr/local/lib/python3.9/dist-packages (from scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.1.4)
# Requirement already satisfied: flax in /usr/local/lib/python3.9/dist-packages (from scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.6.7)
# Collecting pytorch-lightning<1.6,>=1.5
#   Downloading pytorch_lightning-1.5.10-py3-none-any.whl (527 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.7/527.7 KB 51.2 MB/s eta 0:00:00
# Requirement already satisfied: rich>=9.1.0 in /usr/local/lib/python3.9/dist-packages (from scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (13.3.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (1.13.1+cu116)
# Collecting torchmetrics>=0.6.0
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 KB 43.6 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from docrep>=0.3.2->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (1.16.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.9/dist-packages (from jax>=0.3->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (3.3.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.9/dist-packages (from openpyxl>=3.0->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.1->anndata>=0.7.5->scvi-tools-skeleton==0.4.0) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.1->anndata>=0.7.5->scvi-tools-skeleton==0.4.0) (2.8.2)
# Collecting pyro-api>=0.1.1
#   Downloading pyro_api-0.1.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: future>=0.17.1 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.18.3)
# Collecting setuptools==59.5.0
#   Downloading setuptools-59.5.0-py3-none-any.whl (952 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.4/952.4 KB 74.5 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (2.11.2)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (2023.3.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (6.0)
# Collecting pyDeprecate==0.3.1
#   Downloading pyDeprecate-0.3.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (4.5.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich>=9.1.0->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (2.14.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich>=9.1.0->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.2->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.2->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (3.1.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.9/dist-packages (from flax->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (1.0.5)
# Requirement already satisfied: orbax in /usr/local/lib/python3.9/dist-packages (from flax->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.1.6)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.9/dist-packages (from flax->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.1.33)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (5.3.4)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (3.6.3)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (5.7.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (3.0.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (7.9.0)
# Requirement already satisfied: jaxlib>=0.4 in /usr/local/lib/python3.9/dist-packages (from numpyro->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.4.6+cuda11.cudnn86)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.9/dist-packages (from numpyro->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.6.0)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.9/dist-packages (from optax->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (1.4.0)
# Requirement already satisfied: chex>=0.1.5 in /usr/local/lib/python3.9/dist-packages (from optax->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.1.6)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.9/dist-packages (from chex>=0.1.5->optax->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.12.0)
# Requirement already satisfied: dm-tree>=0.1.5 in /usr/local/lib/python3.9/dist-packages (from chex>=0.1.5->optax->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.1.8)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 59.4 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (2.27.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (6.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.7.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (4.8.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 61.3 MB/s eta 0:00:00
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.2.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (2.0.10)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (4.4.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=9.1.0->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.1.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (2.16.2)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (3.19.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (2.2.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (3.4.3)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (1.51.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.40.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.4.6)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.9/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (6.3.0)
# Requirement already satisfied: cached_property in /usr/local/lib/python3.9/dist-packages (from orbax->flax->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (1.5.2)
# Requirement already satisfied: etils in /usr/local/lib/python3.9/dist-packages (from orbax->flax->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (1.1.1)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.9/dist-packages (from orbax->flax->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (1.5.6)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.9/dist-packages (from orbax->flax->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (5.12.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (22.2.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (2.0.12)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 13.2 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 35.5 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 21.7 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.8.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (6.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.17.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (6.5.4)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (5.8.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.16.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (3.1.2)
# Requirement already satisfied: Send2Trash>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (1.8.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (5.3.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (23.2.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.2.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.2.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (2.1.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib_resources->orbax->flax->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (3.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect->ipython>=4.0.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (3.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning<1.6,>=1.5->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (3.2.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (21.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (4.11.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (4.9.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.8.4)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (1.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.7.2)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.2.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (6.0.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (2.16.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (2.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->scvi-tools<0.16.0,>=0.15.0->scvi-tools-skeleton==0.4.0) (2.21)
# Building wheels for collected packages: scvi-tools-skeleton, docrep
#   Building wheel for scvi-tools-skeleton (pyproject.toml) ... done
#   Created wheel for scvi-tools-skeleton: filename=scvi_tools_skeleton-0.4.0-py3-none-any.whl size=11568 sha256=26515211e26097877bb3b7acdce15c4bbc395b561a55e41e3af0f54c14ffc877
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qy29xxei/wheels/ac/1c/65/b58153d82c337843effa074d8fdc71bdf1c079b10ec1ae651c
#   Building wheel for docrep (setup.py) ... done
#   Created wheel for docrep: filename=docrep-0.3.2-py3-none-any.whl size=19891 sha256=cbe5c8b7febdfb787b05103b41730ab83aa37f01b5dab28da05f36e925b9d16e
#   Stored in directory: /root/.cache/pip/wheels/e5/f0/3f/17394a03ed36922f620186a5a9ebd6bce2b4579020243c7a68
# Successfully built scvi-tools-skeleton docrep
# Installing collected packages: pyro-api, setuptools, pyDeprecate, multidict, jedi, frozenlist, docrep, async-timeout, yarl, torchmetrics, pyro-ppl, aiosignal, numpyro, anndata, aiohttp, pytorch-lightning, scvi-tools, scvi-tools-skeleton
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.6.0
#     Uninstalling setuptools-67.6.0:
#       Successfully uninstalled setuptools-67.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cvxpy 1.3.1 requires setuptools>65.5.1, but you have setuptools 59.5.0 which is incompatible.
# arviz 0.15.1 requires setuptools>=60.0.0, but you have setuptools 59.5.0 which is incompatible.
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 anndata-0.8.0 async-timeout-4.0.2 docrep-0.3.2 frozenlist-1.3.3 jedi-0.18.2 multidict-6.0.4 numpyro-0.11.0 pyDeprecate-0.3.1 pyro-api-0.1.2 pyro-ppl-1.8.4 pytorch-lightning-1.5.10 scvi-tools-0.15.5 scvi-tools-skeleton-0.4.0 setuptools-59.5.0 torchmetrics-0.11.4 yarl-1.8.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scanpy
#   Downloading scanpy-1.9.3-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 71.9 MB/s eta 0:00:00
# Collecting session-info
#   Downloading session_info-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.9/dist-packages (from scanpy) (1.2.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from scanpy) (1.1.1)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.9/dist-packages (from scanpy) (1.4.4)
# Collecting umap-learn>=0.3.10
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 KB 632.9 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.9/dist-packages (from scanpy) (3.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.9/dist-packages (from scanpy) (5.5.0)
# Requirement already satisfied: numba>=0.41.0 in /usr/local/lib/python3.9/dist-packages (from scanpy) (0.56.4)
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.9/dist-packages (from scanpy) (1.10.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from scanpy) (23.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.9/dist-packages (from scanpy) (0.12.2)
# Requirement already satisfied: patsy in /usr/local/lib/python3.9/dist-packages (from scanpy) (0.5.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from scanpy) (4.65.0)
# Requirement already satisfied: h5py>=3 in /usr/local/lib/python3.9/dist-packages (from scanpy) (3.8.0)
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /usr/local/lib/python3.9/dist-packages (from scanpy) (0.13.5)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.9/dist-packages (from scanpy) (1.22.4)
# Requirement already satisfied: matplotlib>=3.4 in /usr/local/lib/python3.9/dist-packages (from scanpy) (3.7.1)
# Requirement already satisfied: anndata>=0.7.4 in /usr/local/lib/python3.9/dist-packages (from scanpy) (0.8.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4->scanpy) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4->scanpy) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4->scanpy) (4.39.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4->scanpy) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4->scanpy) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4->scanpy) (5.12.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4->scanpy) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.4->scanpy) (8.4.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.41.0->scanpy) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba>=0.41.0->scanpy) (59.5.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0->scanpy) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22->scanpy) (3.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from patsy->scanpy) (1.16.0)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.8.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 58.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting stdlib_list
#   Downloading stdlib_list-0.8.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 KB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.4->scanpy) (3.15.0)
# Building wheels for collected packages: umap-learn, session-info, pynndescent
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82832 sha256=5d168d403d25f8c507c2b61d0c0fbcf0c86b7c8b74c41f7e3c1bd0230e037a04
#   Stored in directory: /root/.cache/pip/wheels/f4/3e/1c/596d0a463d17475af648688443fa4846fef624d1390339e7e9
#   Building wheel for session-info (setup.py) ... done
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8047 sha256=12dd07cfcafd7e28f756eacded1c4f7dc2eafb9b032309685477a73c346f9c5b
#   Stored in directory: /root/.cache/pip/wheels/d4/fc/2e/00ca60bac7954b84907efd41baa9b4853500eaeec4228410c6
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55512 sha256=e3b06df786a301577c141aae8a55deae966da4c9ce600d4b12e6b197b2db04cc
#   Stored in directory: /root/.cache/pip/wheels/b9/89/cc/59ab91ef5b21dc2ab3635528d7d227f49dfc9169905dcb959d
# Successfully built umap-learn session-info pynndescent
# Installing collected packages: stdlib_list, session-info, pynndescent, umap-learn, scanpy
# Successfully installed pynndescent-0.5.8 scanpy-1.9.3 session-info-1.0.0 stdlib_list-0.8.0 umap-learn-0.5.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting leidenalg
#   Downloading leidenalg-0.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 29.8 MB/s eta 0:00:00
# Collecting igraph<0.11,>=0.10.0
#   Downloading igraph-0.10.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 57.0 MB/s eta 0:00:00
# Collecting texttable>=1.6.2
#   Downloading texttable-1.6.7-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, igraph, leidenalg
# Successfully installed igraph-0.10.4 leidenalg-0.9.1 texttable-1.6.7
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (2.14.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-misc
#   Downloading scikit_misc-0.1.4-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 36.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from scikit-misc) (1.22.4)
# Installing collected packages: scikit-misc
# Successfully installed scikit-misc-0.1.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting typing
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 KB 8.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: typing
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26324 sha256=78f40feb2240c3e090f884e39321bf67a3672d544445adae9d542fa191cab0fb
#   Stored in directory: /root/.cache/pip/wheels/fa/17/1f/332799f975d1b2d7f9b3f33bbccf65031e794717d24432caee
# Successfully built typing
# Installing collected packages: typing
# Successfully installed typing-3.7.4.3

# %%
###### You must restart the runtime in order to use newly installed versions.#####

# %% [markdown]
# **In this part, i impelement the simple vae, in improved part, i impelemented the better result and is similar to base notebook.**

# %%
import scanpy as sc
from mypackage import MyModel, MyPyroModel
from scvi.data import heart_cell_atlas_subsampled

sc.set_figure_params(figsize=(4, 4))

# for white background of figures (only for docs rendering)
# %config InlineBackend.print_figure_kwargs={'facecolor' : "w"}
# %config InlineBackend.figure_format='retina'
# Out:
# INFO:pytorch_lightning.utilities.seed:Global seed set to 0
# /usr/local/lib/python3.9/dist-packages/flax/core/frozen_dict.py:169: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(

# %% [markdown]
# ## Loading and preparing data
#
# Let us first load a subsampled version of the heart cell atlas dataset described in Litviňuková et al. (2020). scvi-tools has many "built-in" datasets as well as support for loading arbitrary `.csv`, `.loom`, and `.h5ad` (AnnData) files. Please see our tutorial on data loading for more examples.
#
# - Litviňuková, M., Talavera-López, C., Maatz, H., Reichart, D., Worth, C. L., Lindberg, E. L., ... & Teichmann, S. A. (2020). Cells of the adult human heart. Nature, 588(7838), 466-472.

# %% [markdown]
# <div class="alert alert-info">
# Important
#
# All scvi-tools models require AnnData objects as input.
#
# </div>

# %%
adata =heart_cell_atlas_subsampled()
# Out:
# INFO     Downloading file at data/hca_subsampled_20k.h5ad
# Downloading...: 100%|██████████| 65714/65714.0 [00:00<00:00, 87343.31it/s]

# %% [markdown]
# Now we preprocess the data to remove, for example, genes that are very lowly expressed and other outliers. For these tasks we prefer the [Scanpy preprocessing module](https://scanpy.readthedocs.io/en/stable/api/index.html#module-scanpy.pp).

# %%
sc.pp.filter_genes(adata, min_counts=3)

# %%
adata.layers["counts"] = adata.X.copy()  # preserve counts
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
adata.raw = adata  # freeze the state in `.raw`

# %%
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=1200,
    subset=True,
    layer="counts",
    flavor="seurat_v3",
    batch_key="cell_source",
)

# %%
MyModel.setup_anndata(adata,
    layer="counts",
    categorical_covariate_keys=["cell_source", "donor"],
    continuous_covariate_keys=["percent_mito", "percent_ribo"])

# %%
n_latent = 10
model = MyModel(adata, n_latent=n_latent)
# Out:
# INFO     mypackage: The model has been initialized

# %%
print(model)
# Out:
# Overwrite this attribute to get an informative representation for your model
# Training status: Not Trained

# %%
model.train()
# Out:
# INFO:pytorch_lightning.utilities.distributed:GPU available: True, used: True
# INFO:pytorch_lightning.utilities.distributed:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.distributed:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.accelerators.gpu:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 400/400: 100%|██████████| 400/400 [12:42<00:00,  1.91s/it, loss=299, v_num=1]

# %%
model.get_elbo()
model.get_latent_representation()
model.get_marginal_ll(n_mc_samples=5)
model.get_reconstruction_error()
# Out:
# {'reconstruction_loss': -273.4199887219369}

# %%
# model.save("my_model/")

# %% [markdown]
# ## Obtaining model outputs

# %%
latent = model.get_latent_representation()

# %%
adata.obsm["X_scVI"] = latent

# %% [markdown]
# First, we demonstrate the presence of nuisance variation with respect to nuclei/whole cell, age group, and donor by plotting the UMAP results of the top 30 PCA components for the raw count data.

# %%
# run PCA then generate UMAP plots
sc.tl.pca(adata)
sc.pp.neighbors(adata, n_pcs=30, n_neighbors=20)
sc.tl.umap(adata, min_dist=0.3)

# %%
sc.pl.umap(
    adata,
    color=["cell_type"],
    frameon=False,
)
sc.pl.umap(
    adata,
    color=["donor", "cell_source"],
    ncols=2,
    frameon=False,
)
# Out:
# /usr/local/lib/python3.9/dist-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /usr/local/lib/python3.9/dist-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /usr/local/lib/python3.9/dist-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
# use scVI latent space for UMAP generation
sc.pp.neighbors(adata, use_rep="X_scVI")
sc.tl.umap(adata, min_dist=0.3)

# %%
sc.pl.umap(
    adata,
    color=["cell_type"],
    frameon=False,
)
sc.pl.umap(
    adata,
    color=["donor", "cell_source"],
    ncols=2,
    frameon=False,
)
# Out:
# /usr/local/lib/python3.9/dist-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /usr/local/lib/python3.9/dist-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /usr/local/lib/python3.9/dist-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
# neighbors were already computed using scVI
sc.tl.leiden(adata, key_added="leiden_scVI", resolution=0.5)

# %%
sc.pl.umap(
    adata,
    color=["leiden_scVI"],
    frameon=False,
)
# Out:
# /usr/local/lib/python3.9/dist-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
